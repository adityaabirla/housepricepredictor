# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(['median_house_value'],axis = 1)
Y = data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
Y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)

# %%
train_data = X_train.join(Y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 700      -122.03     37.69                20.0        200.0            25.0
# 7688     -118.10     33.95                27.0       1666.0           365.0
# 5765     -118.30     34.17                17.0       4041.0          1169.0
# 15815    -122.42     37.76                52.0       2088.0           487.0
# 12577    -121.43     38.53                36.0       2430.0           426.0
# ...          ...       ...                 ...          ...             ...
# 16711    -120.50     35.03                10.0      10463.0          1756.0
# 1327     -121.90     38.02                 5.0       1560.0           369.0
# 4420     -118.26     34.07                46.0       2341.0           703.0
# 14909    -117.04     32.62                26.0       3620.0           607.0
# 9488     -123.36     39.25                17.0       1087.0           254.0
#
#        population  households  median_income ocean_proximity  \
# 700          83.0        31.0         6.5000        NEAR BAY
# 7688        995.0       354.0         4.5694       <1H OCEAN
# 5765       3309.0      1117.0         2.6016       <1H OCEAN
# 15815      1082.0       488.0         2.6803        NEAR BAY
# 12577      1199.0       437.0         3.1667          INLAND
# ...           ...         ...            ...             ...
# 16711      4660.0      1715.0         3.5682       <1H OCEAN
# 1327       1037.0       372.0         3.6154          INLAND
# 4420       2371.0       648.0         2.4038       <1H OCEAN
# 14909      2000.0       593.0         4.9962      NEAR OCEAN
# 9488        522.0       202.0         2.5875       <1H OCEAN
#
#        median_house_value
# 700              340000.0
# 7688             204300.0
# 5765             222400.0
# 15815            490000.0
# 12577             81900.0
# ...                   ...
# 16711            277300.0
# 1327             181800.0
# 4420             181700.0
# 14909            156000.0
# 9488             144500.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.loc[:,train_data.columns != 'ocean_proximity'].corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924553           -0.107510     0.046127
# latitude            -0.924553  1.000000            0.011535    -0.037913
# housing_median_age  -0.107510  0.011535            1.000000    -0.362664
# total_rooms          0.046127 -0.037913           -0.362664     1.000000
# total_bedrooms       0.071402 -0.069295           -0.324017     0.930012
# population           0.098746 -0.107932           -0.295974     0.854920
# households           0.058144 -0.074005           -0.306980     0.919052
# median_income       -0.019034 -0.075950           -0.120632     0.200149
# median_house_value  -0.046040 -0.143858            0.102984     0.136986
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.071402    0.098746    0.058144      -0.019034
# latitude                 -0.069295   -0.107932   -0.074005      -0.075950
# housing_median_age       -0.324017   -0.295974   -0.306980      -0.120632
# total_rooms               0.930012    0.854920    0.919052       0.200149
# total_bedrooms            1.000000    0.874904    0.979795      -0.006104
# population                0.874904    1.000000    0.904608       0.005884
# households                0.979795    0.904608    1.000000       0.014742
# median_income            -0.006104    0.005884    0.014742       1.000000
# median_house_value        0.053210   -0.023086    0.067973       0.688716
#
#                     median_house_value
# longitude                    -0.046040
# latitude                     -0.143858
# housing_median_age            0.102984
# total_rooms                   0.136986
# total_bedrooms                0.053210
# population                   -0.023086
# households                    0.067973
# median_income                 0.688716
# median_house_value            1.000000

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_data.loc[:,train_data.columns != 'ocean_proximity'].corr(),annot = True,cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms']+1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms']+1)
train_data['population'] = np.log(train_data['population']+1)
train_data['households'] = np.log(train_data['households']+1)
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7232
# INLAND        5183
# NEAR OCEAN    2103
# NEAR BAY      1825
# ISLAND           3
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 700        False   False   False      True       False
# 7688        True   False   False     False       False
# 5765        True   False   False     False       False
# 15815      False   False   False      True       False
# 12577      False    True   False     False       False
# ...          ...     ...     ...       ...         ...
# 16711       True   False   False     False       False
# 1327       False    True   False     False       False
# 4420        True   False   False     False       False
# 14909      False   False   False     False        True
# 9488        True   False   False     False       False
#
# [16346 rows x 5 columns]

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis = 1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 700      -122.03     37.69                20.0     5.303305        3.258097
# 7688     -118.10     33.95                27.0     7.418781        5.902633
# 5765     -118.30     34.17                17.0     8.304495        7.064759
# 15815    -122.42     37.76                52.0     7.644441        6.190315
# 12577    -121.43     38.53                36.0     7.796058        6.056784
# ...          ...       ...                 ...          ...             ...
# 16711    -120.50     35.03                10.0     9.255696        7.471363
# 1327     -121.90     38.02                 5.0     7.353082        5.913503
# 4420     -118.26     34.07                46.0     7.758761        6.556778
# 14909    -117.04     32.62                26.0     8.194506        6.410175
# 9488     -123.36     39.25                17.0     6.992096        5.541264
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 700      4.430817    3.465736         6.5000            340000.0      False
# 7688     6.903747    5.872118         4.5694            204300.0       True
# 5765     8.104703    7.019297         2.6016            222400.0       True
# 15815    6.987490    6.192362         2.6803            490000.0      False
# 12577    7.090077    6.082219         3.1667             81900.0      False
# ...           ...         ...            ...                 ...        ...
# 16711    8.446985    7.447751         3.5682            277300.0       True
# 1327     6.945051    5.921578         3.6154            181800.0      False
# 4420     7.771489    6.475433         2.4038            181700.0       True
# 14909    7.601402    6.386879         4.9962            156000.0      False
# 9488     6.259581    5.313206         2.5875            144500.0       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 700     False   False      True       False
# 7688    False   False     False       False
# 5765    False   False     False       False
# 15815   False   False      True       False
# 12577    True   False     False       False
# ...       ...     ...       ...         ...
# 16711   False   False     False       False
# 1327     True   False     False       False
# 4420    False   False     False       False
# 14909   False   False     False        True
# 9488    False   False     False       False
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x = 'latitude',y = 'longitude',data = train_data,hue = 'median_house_value',palette = 'coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms']/train_data['total_rooms']

# %%
train_data['household_rooms'] = train_data['total_rooms']/train_data['households']

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_data.loc[:,train_data.columns != 'ocean_proximity'].corr(),annot = True,cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

X_train,Y_train = train_data.drop(['median_house_value'],axis = 1),train_data['median_house_value']

reg = LinearRegression()
scaler = StandardScaler()

X_train_s = scaler.fit_transform(X_train)

reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
test_data= X_test.join(Y_test)
test_data['total_rooms'] = np.log(test_data['total_rooms']+1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms']+1)
test_data['population'] = np.log(test_data['population']+1)
test_data['households'] = np.log(test_data['households']+1)
test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis = 1)
test_data['bedroom_ratio'] = test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms']/test_data['households']

# %%
X_test,Y_test = test_data.drop(['median_house_value'],axis = 1),test_data['median_house_value']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9176     -118.54     34.38                18.0     7.648263        5.736572
# 8343     -118.33     33.93                38.0     6.543912        4.727388
# 12224    -116.95     33.68                11.0     7.076654        5.187386
# 14018    -117.16     32.74                52.0     6.748760        5.572154
# 12187    -117.31     33.67                 9.0     6.889591        5.135798
# ...          ...       ...                 ...          ...             ...
# 12832    -121.42     38.68                32.0     7.658700        5.846439
# 12736    -121.34     38.59                22.0     8.093768        6.175867
# 10405    -117.53     33.69                 6.0     6.120297        4.634729
# 4765     -118.35     34.04                38.0     7.394493        5.929589
# 881      -121.99     37.56                20.0     8.773849        7.166266
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 9176     6.951772    5.796058         6.8299            262100.0       True
# 8343     6.023448    4.787492         6.0718            156000.0       True
# 12224    6.298949    4.997212         4.4792            173900.0      False
# 14018    5.966147    5.521461         2.6042            225000.0      False
# 12187    6.391917    5.056246         3.1832            157400.0       True
# ...           ...         ...            ...                 ...        ...
# 12832    6.927558    5.826000         3.7250            112200.0      False
# 12736    7.049255    6.139885         8.0500            380000.0      False
# 10405    5.365976    3.784190        10.9704            483300.0       True
# 4765     6.927558    5.921578         2.3687            146800.0       True
# 881      8.098339    7.119636         4.3393            231200.0       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 9176    False   False     False       False       0.750049         1.319563
# 8343    False   False     False       False       0.722410         1.366877
# 12224    True   False     False       False       0.733028         1.416120
# 14018   False   False     False        True       0.825656         1.222278
# 12187   False   False     False       False       0.745443         1.362590
# ...       ...     ...       ...         ...            ...              ...
# 12832    True   False     False       False       0.763372         1.314573
# 12736    True   False     False       False       0.763040         1.318228
# 10405   False   False     False       False       0.757272         1.617334
# 4765    False   False     False       False       0.801893         1.248737
# 881     False   False     False       False       0.816776         1.232345
#
# [4087 rows x 16 columns]

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 700      -122.03     37.69                20.0     5.303305        3.258097
# 7688     -118.10     33.95                27.0     7.418781        5.902633
# 5765     -118.30     34.17                17.0     8.304495        7.064759
# 15815    -122.42     37.76                52.0     7.644441        6.190315
# 12577    -121.43     38.53                36.0     7.796058        6.056784
# ...          ...       ...                 ...          ...             ...
# 16711    -120.50     35.03                10.0     9.255696        7.471363
# 1327     -121.90     38.02                 5.0     7.353082        5.913503
# 4420     -118.26     34.07                46.0     7.758761        6.556778
# 14909    -117.04     32.62                26.0     8.194506        6.410175
# 9488     -123.36     39.25                17.0     6.992096        5.541264
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 700      4.430817    3.465736         6.5000            340000.0      False
# 7688     6.903747    5.872118         4.5694            204300.0       True
# 5765     8.104703    7.019297         2.6016            222400.0       True
# 15815    6.987490    6.192362         2.6803            490000.0      False
# 12577    7.090077    6.082219         3.1667             81900.0      False
# ...           ...         ...            ...                 ...        ...
# 16711    8.446985    7.447751         3.5682            277300.0       True
# 1327     6.945051    5.921578         3.6154            181800.0      False
# 4420     7.771489    6.475433         2.4038            181700.0       True
# 14909    7.601402    6.386879         4.9962            156000.0      False
# 9488     6.259581    5.313206         2.5875            144500.0       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 700     False   False      True       False       0.614352         1.530210
# 7688    False   False     False       False       0.795634         1.263391
# 5765    False   False     False       False       0.850715         1.183095
# 15815   False   False      True       False       0.809780         1.234495
# 12577    True   False     False       False       0.776903         1.281779
# ...       ...     ...       ...         ...            ...              ...
# 16711   False   False     False       False       0.807218         1.242750
# 1327     True   False     False       False       0.804221         1.241744
# 4420    False   False     False       False       0.845081         1.198184
# 14909   False   False     False        True       0.782253         1.283022
# 9488    False   False     False       False       0.792504         1.315984
#
# [16346 rows x 16 columns]

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9176     -118.54     34.38                18.0     7.648263        5.736572
# 8343     -118.33     33.93                38.0     6.543912        4.727388
# 12224    -116.95     33.68                11.0     7.076654        5.187386
# 14018    -117.16     32.74                52.0     6.748760        5.572154
# 12187    -117.31     33.67                 9.0     6.889591        5.135798
# ...          ...       ...                 ...          ...             ...
# 12832    -121.42     38.68                32.0     7.658700        5.846439
# 12736    -121.34     38.59                22.0     8.093768        6.175867
# 10405    -117.53     33.69                 6.0     6.120297        4.634729
# 4765     -118.35     34.04                38.0     7.394493        5.929589
# 881      -121.99     37.56                20.0     8.773849        7.166266
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 9176     6.951772    5.796058         6.8299       True   False   False
# 8343     6.023448    4.787492         6.0718       True   False   False
# 12224    6.298949    4.997212         4.4792      False    True   False
# 14018    5.966147    5.521461         2.6042      False   False   False
# 12187    6.391917    5.056246         3.1832       True   False   False
# ...           ...         ...            ...        ...     ...     ...
# 12832    6.927558    5.826000         3.7250      False    True   False
# 12736    7.049255    6.139885         8.0500      False    True   False
# 10405    5.365976    3.784190        10.9704       True   False   False
# 4765     6.927558    5.921578         2.3687       True   False   False
# 881      8.098339    7.119636         4.3393       True   False   False
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 9176      False       False       0.750049         1.319563
# 8343      False       False       0.722410         1.366877
# 12224     False       False       0.733028         1.416120
# 14018     False        True       0.825656         1.222278
# 12187     False       False       0.745443         1.362590
# ...         ...         ...            ...              ...
# 12832     False       False       0.763372         1.314573
# 12736     False       False       0.763040         1.318228
# 10405     False       False       0.757272         1.617334
# 4765      False       False       0.801893         1.248737
# 881       False       False       0.816776         1.232345
#
# [4087 rows x 15 columns]

# %%
Y_test
# Out:
# 9176     262100.0
# 8343     156000.0
# 12224    173900.0
# 14018    225000.0
# 12187    157400.0
#            ...
# 12832    112200.0
# 12736    380000.0
# 10405    483300.0
# 4765     146800.0
# 881      231200.0
# Name: median_house_value, Length: 4087, dtype: float64

# %%
reg.score(X_test,Y_test)
# Out:
# 0.6669153059223039

# %%
X_test_s = scaler.transform(X_test)

# %%
X_test_s
# Out:
# array([[ 0.51445824, -0.58549554, -0.84438743, ..., -0.38425444,
#         -1.13378818,  0.49107637],
#        [ 0.61939547, -0.79621515,  0.74473892, ..., -0.38425444,
#         -1.87870896,  1.09357003],
#        [ 1.30898295, -0.9132816 , -1.40058165, ..., -0.38425444,
#         -1.59253471,  1.72063345],
#        ...,
#        [ 1.01915633, -0.90859894, -1.79786324, ..., -0.38425444,
#         -0.93911986,  4.28287538],
#        [ 0.60940145, -0.74470591,  0.74473892, ..., -0.38425444,
#          0.26349047, -0.41082   ],
#        [-1.20951046,  0.90358971, -0.6854748 , ..., -0.38425444,
#          0.6646161 , -0.6195502 ]])

# %%
reg.score(X_test_s,Y_test)
# Out:
# /Users/adityabirla/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# -373.04810116878343

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test,Y_test)
# Out:
# 0.8107923830080687

# %%
from sklearn.model_selection import GridSearchCV
forest = RandomForestRegressor()
param_grid = {
"n_estimators":[30,100,150],
"min_samples_split":[4,6,10],
"max_depth":[None,1,2]
}
grid_search = GridSearchCV(forest,param_grid,cv = 5,scoring = "neg_mean_squared_error",return_train_score=True)
grid_search.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 1, 2],
#                          'min_samples_split': [4, 6, 10],
#                          'n_estimators': [30, 100, 150]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(min_samples_split=4, n_estimators=150)

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test,Y_test)
# Out:
# 0.8147579150960762
